# %% [markdown]
# # 데이터 handling

# %% [markdown]
# - 데이터 구조
#     - Series
#     - DataFrame
# - 데이터 읽기 및 저정
#     - Series 구조 데이터 생성하기
#     - DataFrame 구조 데이터 생성하기
# - 데이터 내용 확인
#     - 데이터 읽어오기
#     - 데이터의 내용 미리보기
#     - 요약정보 확인하기
#     - 데이터 개수 및 집계함수 활용

# %% [markdown]
# ## 데이터 구조
# - pandas 패키지란?
#     - 데이터를 수집하고 정리하는데 최적화된 도구
#         - numpy 기반으로 작성된 라이브러리로 데이터 불러오기 , 전처리 , 통계분석에 사용
#         - Series 형태와 DataFrame 형태의 자료구조 존재
#         - 실무에서 접하는 엑셀 파일의 스프레드 시트가 DataFrame 형태임
#         - 데이터 분석에 있어서 필수적인 라이브러리로 데이터 전처리시 대부분은 pandas를 사용함
#
# - 데이터 구조
#     - Series: 1차원 배열 구조로 index와 values로 구성
#     - DataFrame: spreadsheet(m*n)의 행렬 구조 형식의 자료구조로 inde, columns, values 형태로 구성

# %% [markdown]
# ### 연습

# %%
# 패키지 불러오기 
import pandas as pd

# %%
dict_data={'a':1,"b":2,"c":3}
sr=pd.Series(dict_data)
print(type(sr))
print(sr)
# Out:
# <class 'pandas.core.series.Series'>
# a    1
# b    2
# c    3
# dtype: int64

# %%
table={"일자":['2019-01-01','2019-01-04','2017-01-07','2019-01-10','2019-01-13'],
      "가격":[1000,1500,2000,2500,3000],
      "구매여부":['False','True','True','True','True'],
      "제품":['gum','snack','beverage','dongas','alchoal']}

df=pd.DataFrame(table)
df
# Out:
#            일자    가격   구매여부        제품
# 0  2019-01-01  1000  False       gum
# 1  2019-01-04  1500   True     snack
# 2  2017-01-07  2000   True  beverage
# 3  2019-01-10  2500   True    dongas
# 4  2019-01-13  3000   True   alchoal

# %% [markdown]
# ### 실습 1.

# %%
name={1:"홍길동",2:"아순신",3:"강감찬"}

name_df=pd.Series(name)
name_df
# Out:
# 1    홍길동
# 2    아순신
# 3    강감찬
# dtype: object

# %%
score={"성명":["홍길동","이순신",",강감찬","이성계","정약용"],"국어성적":[90,95,85,90,95],
      "영어성적":[90,85,90,95,95],"수학성적":[95,90,85,75,90]}

score_df=pd.DataFrame(score)
score_df
# Out:
#      성명  국어성적  영어성적  수학성적
# 0   홍길동    90    90    95
# 1   이순신    95    85    90
# 2  ,강감찬    85    90    85
# 3   이성계    90    95    75
# 4   정약용    95    95    90

# %%
df=pd.read_csv("./FITNESS.csv" , encoding='euc-kr')
df.head()
# Out:
#      NAME GENDER  AGE AGEGROUP  WEIGHT     OXY  RUNTIME  RUNPULSE  RSTPULSE  \
# 0   Donna     여성   42      40대   68.15  59.571     8.17       166        40
# 1  Gracie     여성   38      30대   81.87  60.055     8.63       170        48
# 2  Luanne     여성   43      40대   85.84  54.297     8.65       156        45
# 3    Mimi     여성   50      50대   70.87  54.625     8.92       146        48
# 4   Chris     남성   49      40대   81.42  49.156     8.95       180        44
#
#    MAXPULSE
# 0       172
# 1       186
# 2       168
# 3       155
# 4       185

# %%
df=pd.read_excel("./성적처리.xlsx" , sheet_name='Sheet1')
df.head()
# Out:
#     반   성명  국어  영어  수학  사회  과학
# 0  1반  홍길동  93  80  94  73  64
# 1  5반  백일홍  93  63  76  84  92
# 2  3반  이삼상  94  74  86  90  70
# 3  4반  정말로  83  55  64  90  65
# 4  5반  한번도  87  95  66  75  60

# %% [markdown]
# ### 실습 2.

# %%
df=pd.read_csv("./성적.csv" , encoding='euc-kr',index_col=0)
df
# Out:
#     성명  국어성적  영어성적  수학성적
# 0  홍길동    90    90    95
# 1  이순신    95    85    90
# 2  강감찬    85    90    85
# 3  이성계    90    95    75
# 4  정약용    95    95    90

# %%
df.to_csv("./성적실습.csv")

# %% [markdown]
# # 데이터 내용확인

# %%
df=pd.read_csv("./auto_mpg.csv")

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  modelyear  \
# 0  18.0          8         307.0        130    3504          12.0         70
# 1  15.0          8         350.0        165    3693          11.5         70
# 2  18.0          8         318.0        150    3436          11.0         70
# 3  16.0          8         304.0        150    3433          12.0         70
# 4  17.0          8         302.0        140    3449          10.5         70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      modelyear  origin             name
# 393         82       1  ford mustang gl
# 394         82       2        vw pickup
# 395         82       1    dodge rampage
# 396         82       1      ford ranger
# 397         82       1       chevy s-10

# %%
df.shape
# Out:
# (398, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   modelyear     398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# modelyear         int64
# origin            int64
# name             object
# dtype: object

# %%
df.mpg.dtypes
# Out:
# dtype('float64')

# %%
# 요약 정보 확인 
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#         modelyear      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df.describe(include='all')
# Out:
#                mpg   cylinders  displacement horsepower       weight  \
# count   398.000000  398.000000    398.000000        398   398.000000
# unique         NaN         NaN           NaN         94          NaN
# top            NaN         NaN           NaN        150          NaN
# freq           NaN         NaN           NaN         22          NaN
# mean     23.514573    5.454774    193.425879        NaN  2970.424623
# std       7.815984    1.701004    104.269838        NaN   846.841774
# min       9.000000    3.000000     68.000000        NaN  1613.000000
# 25%      17.500000    4.000000    104.250000        NaN  2223.750000
# 50%      23.000000    4.000000    148.500000        NaN  2803.500000
# 75%      29.000000    8.000000    262.000000        NaN  3608.000000
# max      46.600000    8.000000    455.000000        NaN  5140.000000
#
#         acceleration   modelyear      origin        name
# count     398.000000  398.000000  398.000000         398
# unique           NaN         NaN         NaN         305
# top              NaN         NaN         NaN  ford pinto
# freq             NaN         NaN         NaN           6
# mean       15.568090   76.010050    1.572864         NaN
# std         2.757689    3.697627    0.802055         NaN
# min         8.000000   70.000000    1.000000         NaN
# 25%        13.825000   73.000000    1.000000         NaN
# 50%        15.500000   76.000000    1.000000         NaN
# 75%        17.175000   79.000000    2.000000         NaN
# max        24.800000   82.000000    3.000000         NaN

# %%
print(df.count())
# Out:
# mpg             398
# cylinders       398
# displacement    398
# horsepower      398
# weight          398
# acceleration    398
# modelyear       398
# origin          398
# name            398
# dtype: int64

# %%
unique_value=df['origin'].value_counts()
unique_value
# Out:
# 1    249
# 3     79
# 2     70
# Name: origin, dtype: int64

# %%
df.groupby(['cylinders'],as_index=False).mean()
# Out:
# /tmp/ipykernel_8890/3275713371.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['cylinders'],as_index=False).mean()
#    cylinders        mpg  displacement       weight  acceleration  modelyear  \
# 0          3  20.550000     72.500000  2398.500000     13.250000  75.500000
# 1          4  29.286765    109.796569  2308.127451     16.601471  77.073529
# 2          5  27.366667    145.000000  3103.333333     18.633333  79.000000
# 3          6  19.985714    218.142857  3198.226190     16.263095  75.928571
# 4          8  14.963107    345.009709  4114.718447     12.955340  73.902913
#
#      origin
# 0  3.000000
# 1  1.985294
# 2  2.000000
# 3  1.190476
# 4  1.000000

# %%
df.groupby(['cylinders'],as_index=False)['weight','acceleration'].mean()
# Out:
# /tmp/ipykernel_8890/3672610226.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['cylinders'],as_index=False)['weight','acceleration'].mean()
#    cylinders       weight  acceleration
# 0          3  2398.500000     13.250000
# 1          4  2308.127451     16.601471
# 2          5  3103.333333     18.633333
# 3          6  3198.226190     16.263095
# 4          8  4114.718447     12.955340

# %%
df.groupby(['cylinders','modelyear'],as_index=False).agg(['mean','median'])
# Out:
# /tmp/ipykernel_8890/2777413220.py:1: FutureWarning: ['horsepower', 'name'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby(['cylinders','modelyear'],as_index=False).agg(['mean','median'])
#                            mpg        displacement              weight  \
#                           mean median         mean median         mean
# cylinders modelyear
# 3         72         19.000000  19.00    70.000000   70.0  2330.000000
#           73         18.000000  18.00    70.000000   70.0  2124.000000
#           77         21.500000  21.50    80.000000   80.0  2720.000000
#           80         23.700000  23.70    70.000000   70.0  2420.000000
# 4         70         25.285714  25.00   107.000000  107.0  2292.571429
#           71         27.461538  27.00   101.846154   97.0  2056.384615
#           72         23.428571  23.00   111.535714  116.5  2382.642857
#           73         22.727273  22.00   109.272727  114.0  2338.090909
#           74         27.800000  26.00    96.533333   90.0  2151.466667
#           75         25.250000  24.00   114.833333  119.5  2489.250000
#           76         26.766667  27.00   106.333333   98.0  2306.600000
#           77         29.107143  30.00   106.500000   98.0  2205.071429
#           78         29.576471  29.50   112.117647  105.0  2296.764706
#           79         31.525000  32.70   113.583333  105.0  2357.583333
#           80         34.612000  33.80   111.000000   98.0  2360.080000
#           81         32.814286  33.00   108.857143  105.0  2275.476190
#           82         32.071429  32.00   118.571429  112.0  2402.321429
# 5         78         20.300000  20.30   131.000000  131.0  2830.000000
#           79         25.400000  25.40   183.000000  183.0  3530.000000
#           80         36.400000  36.40   121.000000  121.0  2950.000000
# 6         70         20.500000  21.00   199.000000  199.0  2710.500000
#           71         18.000000  18.00   243.375000  250.0  3171.875000
#           73         19.000000  18.00   212.250000  228.5  2917.125000
#           74         17.857143  18.00   230.428571  232.0  3320.000000
#           75         17.583333  18.00   233.750000  232.0  3398.333333
#           76         20.000000  19.50   221.400000  228.5  3349.600000
#           77         19.500000  19.00   220.400000  231.0  3383.000000
#           78         19.066667  19.30   213.250000  225.0  3314.166667
#           79         22.950000  21.05   205.666667  212.5  3025.833333
#           80         25.900000  25.90   196.500000  196.5  3145.500000
#           81         23.428571  23.50   184.000000  173.0  3093.571429
#           82         28.333333  25.00   225.000000  232.0  2931.666667
